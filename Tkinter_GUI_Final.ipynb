# %%
# Out:
# Hi

# %%
# Out:
# Hi

# %%
import tkinter as tk
win=tk.Tk()
#####To select Budget
def sel_budget():
   selection = "Budget =  " + str(var.get())
   label.config(text = selection)
######Budget
var = tk.StringVar()
BudLab=tk.Label(win,text="BUDGET",font=("Times New Roman",15,"bold"),bg="Light Grey")
BudLab.place(x=100,y=170)
R1 = tk.Radiobutton(win, text="Below 10L", variable=var, value="Below 10L",
                  command=sel_budget)
R1.place(x=100,y=230)

R2 = tk.Radiobutton(win, text="10L to 50L", variable=var, value="10L to 50L",
                  command=sel_budget)
R2.place(x=300,y=230)

R3 = tk.Radiobutton(win, text="Above 50L", variable=var, value="Above 50L",
                  command=sel_budget)
R3.place(x=500,y=230)

label = tk.Label(win,font=("Times New Roman",12,"bold"),relief=tk.RAISED,width=25 )
label.place(x=1000,y=230)

###Select daily travel
def sel_dailyTravel():
   selection = "Value = " + str(var1.get()) +" km"
   label1.config(text = selection)

#####Daily Travel
TraLab=tk.Label(win,text="DAILY TRAVEL",font=("Times New Roman",15,"bold"),bg="Light Grey")
TraLab.place(x=100,y=290)
var1 = tk.DoubleVar()
scale = tk.Scale( win, variable = var1,orient=tk.HORIZONTAL,length=500)
scale.place(x=100,y=330)

button = tk.Button(win, text="Get Value", command=sel_dailyTravel)
button.place(x=800,y=350)

label1 = tk.Label(win,font=("Times New Roman",12,"bold"),relief=tk.RAISED,width=25 )
label1.place(x=1000,y=350)

#####To select Fuel
def sel_Fuel():
   selection = "Fuel =  " + str(var2.get())
   label2.config(text = selection)
######Fuel

FuLab=tk.Label(win,text="FUEL",font=("Times New Roman",15,"bold"),bg="Light Grey")
FuLab.place(x=100,y=400)
var2 = tk.StringVar()
R31 = tk.Radiobutton(win, text="Any", variable=var2, value="Any",
                  command=sel_Fuel)
R31.place(x=100,y=450)

R11 = tk.Radiobutton(win, text="Petrol", variable=var2, value="Petrol",
                  command=sel_Fuel)
R11.place(x=250,y=450)

R21 = tk.Radiobutton(win, text="Diesel", variable=var2, value="Diesel",
                  command=sel_Fuel)
R21.place(x=400,y=450)

R31 = tk.Radiobutton(win, text="CNG+Petrol", variable=var2, value="CNG+Petrol",
                  command=sel_Fuel)
R31.place(x=550,y=450)

R31 = tk.Radiobutton(win, text="CNG+Diesel", variable=var2, value="CNG+Diesel",
                  command=sel_Fuel)
R31.place(x=700,y=450)

R31 = tk.Radiobutton(win, text="Hybrid", variable=var2, value="Hybrid",
                  command=sel_Fuel)
R31.place(x=850,y=450)



label2 = tk.Label(win,font=("Times New Roman",12,"bold"),relief=tk.RAISED,width=25 )
label2.place(x=1000,y=450)

#####To select Model
def sel_Model(val):
   selection = "Model =  " + val
   label3.config(text = selection)
######Fuel

MoLab=tk.Label(win,text="Model",font=("Times New Roman",15,"bold"),bg="Light Grey")
MoLab.place(x=100,y=500)
var3 = tk.StringVar()
R12 = tk.Button(win, text="Any",width=20,
                  command=lambda:sel_Model("Any"))
R12.place(x=100,y=550)

R13 = tk.Button(win, text="Sedan", width=20,
                  command=lambda:sel_Model("Sedan"))
R13.place(x=300,y=550)

R14 = tk.Button(win, text="SUV", width=20,
                  command=lambda:sel_Model("SUV"))
R14.place(x=500,y=550)

R15 = tk.Button(win, text="Convertible", width=20,
                  command=lambda:sel_Model("Convertible"))
R15.place(x=200,y=600)

R16 = tk.Button(win, text="Hatchback",width=20, 
                  command=lambda:sel_Model("Hatchback"))
R16.place(x=400,y=600)

label3 = tk.Label(win,font=("Times New Roman",12,"bold"),relief=tk.RAISED,width=25 )
label3.place(x=1000,y=550)



win.title("CarDekho")
win.resizable(True,True)
win.configure(background='Light Grey')
Welcome=tk.Label(win,text="WELCOME TO CAR DEKHO!",relief=tk.RAISED,font=("Times New Roman",19,"bold"),fg="black",justify=tk.CENTER,padx=520)
Welcome.place(x=0,y=0)

win.mainloop()

#budget (scrollbar)
#engine_power (scrollbar)
#mileage (radio_buttons)
#seater

# %%
import tkinter as tk
win=tk.Tk()


###Select daily travel
def sel_Budget():
   selection = "Value = " + str(budget.get())+ "L" 
   label.config(text = selection)

#####Budget
TraLab=tk.Label(win,text="BUDGET (Lakhs)",font=("Times New Roman",15,"bold"),bg="Light Grey")
TraLab.place(x=100,y=170)
budget = tk.IntVar()
scale = tk.Scale( win, variable = budget,orient=tk.HORIZONTAL,length=500,from_=1)
scale.place(x=100,y=230)

button = tk.Button(win, text="Get Value", command=sel_Budget)
button.place(x=800,y=250)

label = tk.Label(win,font=("Times New Roman",12,"bold"),relief=tk.RAISED,width=25 )
label.place(x=1000,y=250)

#####To select Fuel
def sel_Mileage():
    if(mileage.get()==1):
        selection = " Any "
        label1.config(text = selection)
    else:
        selection = "Mileage =  " + str(mileage.get())+"kmpl"
        label1.config(text = selection)
   
######Fuel

MilLab=tk.Label(win,text="MILEAGE",font=("Times New Roman",15,"bold"),bg="Light Grey")
MilLab.place(x=100,y=290)
mileage = tk.IntVar()

R31 = tk.Radiobutton(win, text="Any", variable=mileage, value=1,
                  command=sel_Mileage)
R31.place(x=100,y=330)

R11 = tk.Radiobutton(win, text="10", variable=mileage, value=10,
                  command=sel_Mileage)
R11.place(x=250,y=330)

R21 = tk.Radiobutton(win, text="15", variable=mileage, value=15,
                  command=sel_Mileage)
R21.place(x=400,y=330)

R31 = tk.Radiobutton(win, text="20", variable=mileage, value=20,
                  command=sel_Mileage)
R31.place(x=550,y=330)

R31 = tk.Radiobutton(win, text="25", variable=mileage, value=25,
                  command=sel_Mileage)
R31.place(x=700,y=330)

R31 = tk.Radiobutton(win, text="30", variable=mileage, value=30,
                  command=sel_Mileage)
R31.place(x=850,y=330)



label1 = tk.Label(win,font=("Times New Roman",12,"bold"),relief=tk.RAISED,width=25 )
label1.place(x=1000,y=350)



###Select Performance
def sel_Perfomance():
   selection = " " + str(performance.get())
   label2.config(text = selection)

#####Performance
PerLab=tk.Label(win,text="PERFORMANCE (Low to High)",font=("Times New Roman",15,"bold"),bg="Light Grey")
PerLab.place(x=100,y=390)
performance= tk.IntVar()
scale = tk.Scale( win, variable = performance,orient=tk.HORIZONTAL,length=500,from_=1, to=10)
scale.place(x=100,y=430)

button = tk.Button(win, text="Get Value", command=sel_Perfomance)
button.place(x=800,y=430)

label2 = tk.Label(win,font=("Times New Roman",12,"bold"),relief=tk.RAISED,width=25 )
label2.place(x=1000,y=430)



#####To select Seater
def sel_Seater(seats):
    if(seats==0):
        selection = " Any "
        label3.config(text = selection)
    else:
       selection = str(seats)+ " Seater"
       label3.config(text = selection)
######Seater

MoLab=tk.Label(win,text="Seater",font=("Times New Roman",15,"bold"),bg="Light Grey")
MoLab.place(x=100,y=500)

R12 = tk.Button(win, text="Any",width=20,
                  command=lambda:sel_Seater(0))
R12.place(x=100,y=550)

R13 = tk.Button(win, text="2 Seater", width=20,
                  command=lambda:sel_Seater(2))
R13.place(x=300,y=550)

R14 = tk.Button(win, text="4 Seater", width=20,
                  command=lambda:sel_Seater(4))
R14.place(x=500,y=550)

R15 = tk.Button(win, text="5 Seater", width=20,
                  command=lambda:sel_Seater(5))
R15.place(x=700,y=550)

R16 = tk.Button(win, text="6 Seater",width=20, 
                  command=lambda:sel_Seater(6))
R16.place(x=200,y=600)

R16 = tk.Button(win, text="7 Seater",width=20, 
                  command=lambda:sel_Seater(7))
R16.place(x=400,y=600)

R16 = tk.Button(win, text="9 Seater",width=20, 
                  command=lambda:sel_Seater(9))
R16.place(x=600,y=600)

label3 = tk.Label(win,font=("Times New Roman",12,"bold"),relief=tk.RAISED,width=25 )
label3.place(x=1000,y=550)



win.title("CarDekho")
win.resizable(True,True)
win.configure(background='Light Grey')
Welcome=tk.Label(win,text="WELCOME TO CAR DEKHO!",relief=tk.RAISED,font=("Times New Roman",19,"bold"),fg="black",justify=tk.CENTER,padx=520)
Welcome.place(x=0,y=0)

win.mainloop()

#budget (scrollbar)
#engine_power (scrollbar)
#mileage (radio_buttons)
#seater

# %%
#####To select Budget
def sel_budget():
   selection = "Budget =  " + str(var.get())
   label.config(text = selection)
######Budget
var = tk.StringVar()
BudLab=tk.Label(win,text="BUDGET",font=("Times New Roman",15,"bold"),bg="Light Grey")
BudLab.place(x=100,y=170)
R1 = tk.Radiobutton(win, text="Below 10L", variable=var, value="Below 10L",
                  command=sel_budget)
R1.place(x=100,y=230)

R2 = tk.Radiobutton(win, text="10L to 50L", variable=var, value="10L to 50L",
                  command=sel_budget)
R2.place(x=300,y=230)

R3 = tk.Radiobutton(win, text="Above 50L", variable=var, value="Above 50L",
                  command=sel_budget)
R3.place(x=500,y=230)

label = tk.Label(win,font=("Times New Roman",12,"bold"),relief=tk.RAISED,width=25 )
label.place(x=1000,y=230)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-c63ba26deba1> in <module>
#       4    label.config(text = selection)
#       5 ######Budget
# ----> 6 var = tk.StringVar()
#       7 BudLab=tk.Label(win,text="BUDGET",font=("Times New Roman",15,"bold"),bg="Light Grey")
#       8 BudLab.place(x=100,y=170)
#
# ~/anaconda3/lib/python3.7/tkinter/__init__.py in __init__(self, master, value, name)
#     478         then the existing value is retained.
#     479         """
# --> 480         Variable.__init__(self, master, value, name)
#     481
#     482     def get(self):
#
# ~/anaconda3/lib/python3.7/tkinter/__init__.py in __init__(self, master, value, name)
#     315         if not master:
#     316             master = _default_root
# --> 317         self._root = master._root()
#     318         self._tk = master.tk
#     319         if name:
#
# ...
